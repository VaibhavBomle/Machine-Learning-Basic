# %% [markdown]
# **Imbalanced Dataset :**
#
# A dataset with unequal class disribution

# %%
# importing the dependencies
import numpy as np
import pandas as pd

# %%
# loading the dataset to pandas DataFrame
credit_card_data = pd.read_csv('/content/credit_data.csv')

# %%
# first 5 rows of data frame
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
credit_card_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 223853  143550.0 -0.841297  0.826026  0.653840  0.081422  0.944247 -0.946773
# 223854  143551.0  1.961248 -0.047037 -1.924226  0.403639  0.226717 -1.054853
# 223855  143551.0 -0.995266  0.689360 -0.129920 -1.019210 -0.004685 -0.737544
# 223856  143552.0  2.072290 -0.059782 -1.128102  0.382643 -0.078541 -1.131168
# 223857  143552.0  1.863110 -0.366371 -0.058167  1.266312 -0.528037  0.277019
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 223853  1.359069 -0.366209 -0.620152  ...  0.026863  0.219923 -0.430668
# 223854  0.125899 -0.159526  0.557552  ...  0.227594  0.644476 -0.090823
# 223855  1.442358  0.007701 -0.191575  ... -0.038218 -0.128516  0.067555
# 223856  0.177014 -0.321608  0.562317  ... -0.299667 -0.732141  0.322664
# 223857 -0.749884  0.166159  1.152601  ...       NaN       NaN       NaN
#
#              V24       V25       V26       V27       V28  Amount  Class
# 223853  0.011801  1.034302  0.079031 -0.103068  0.071854   29.99    0.0
# 223854 -0.445101  0.204299 -0.100417 -0.021754 -0.038624   41.66    0.0
# 223855 -0.020188 -0.496044  0.137714 -0.423308 -0.157237  123.50    0.0
# 223856 -0.112296 -0.281154  0.205301 -0.071423 -0.061553    1.98    0.0
# 223857       NaN       NaN       NaN       NaN       NaN     NaN    NaN
#
# [5 rows x 31 columns]

# %%
# distribution of the two classes
credit_card_data['Class'].value_counts()
# Out:
# 0.0    223442
# 1.0       415
# Name: Class, dtype: int64

# %% [markdown]
# This is highly imbalanced Dataset

# %% [markdown]
# 0 --> Legit Transactions
#
# 1 --> Fradulent Transections

# %%
# sperating the legit and fradulent transactions
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (223442, 31)
# (415, 31)

# %% [markdown]
# Under-sampling

# %% [markdown]
# Build a sample dataset containing similar distribution of Legit & Fradulent Transactions
#
# Number of Fradulent Transactions --> 492

# %%
legit_sample = legit.sample(n=415)

# %%
print(legit_sample.shape)
# Out:
# (415, 31)

# %% [markdown]
# Concatenate the Two DataFrames

# %%
new_dataset = pd.concat([legit_sample,fraud],axis = 0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 206568  136261.0  0.878862 -2.769036 -1.329463  1.004904 -1.463248  0.156821
# 54712    46581.0 -2.265029  1.249844  0.025703 -1.271750 -0.255792 -0.739949
# 155987  106932.0  1.969526 -0.153928  0.026247  0.649756 -0.878359 -1.047176
# 14762    25996.0 -4.077991 -2.625379 -0.106670 -0.885107 -7.570740  4.714293
# 1515      1180.0 -1.504151  1.323300  0.497858 -2.486798 -0.600184  0.649879
#
#               V7        V8        V9  ...       V21       V22       V23  \
#